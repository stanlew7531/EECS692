# %%
import os
import yaml
import numpy as np
from kpnet.utils.imgproc import PixelCoord, pixel_in_bbox
from kpnet.utils.transformations import quaternion_matrix
from kpnet.dataHandling.keypoint_db_entry import KeypointDBEntry
from kpnet.dataHandling.keypoint_db import KeypointDB, KeypointDBConfig
from kpnet.dataHandling.keypoint_loader import KeypointDatasetConfig, ProcessedEntry, KeypointDataset
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import kpnet.config.parameter as parameter
from kpnet.network.resnetNoStage import ResnetNoStage
from kpnet.network.resnetBackbone import ResnetConfig, initialize_backbone_from_modelzoo
import kpnet.network.predict as predict
from kpnet.network.losses import weighted_mse_loss, weighted_l1_loss
import time

# %% [markdown]
# # Load dataset into KeypointDB

# %%
kpDbConfig = KeypointDBConfig()
kpDbConfig.pdc_data_root = "/home/stanlew/src/kpam/data/"
#kpDbConfig.config_file_path = "/home/stanlew/src/kpam/mankey_recreate/kpnet/config/mugs_test_single.txt"
#kpDbConfig.config_file_path = "/home/stanlew/src/kpam/mankey_recreate/kpnet/config/mugs_20190221.txt"
kpDbConfig.config_file_path = "/home/stanlew/src/kpam/mankey_recreate/kpnet/config/mugs_alldata.txt"
kpDbConfig.keypoint_yaml_name = "mug_3_keypoint_image.yaml"

# %%
kpDb_train = KeypointDB(kpDbConfig)
# Out:
# invalid scene entry: /home/stanlew/src/kpam/data/logs_proto/2019-02-15-03-57-26
# invalid scene entry: /home/stanlew/src/kpam/data/logs_proto/2019-02-15-03-16-31
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-17-32-07
# /home/stanlew/src/kpam/mankey_recreate/kpnet/dataHandling/keypoint_db.py:125: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   keypoint_yaml_data = yaml.load(keypoint_yaml_file_handle)
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-17-34-32
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-17-36-30
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-17-43-26
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-17-45-21
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-17-47-10
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-17-49-03
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-17-50-59
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-17-53-41
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-17-56-41
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-17-59-10
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-09-18-01-12
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-14-22-31-21
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-14-22-33-14
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-14-22-35-08
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-14-22-47-49
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-14-22-50-02
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-14-22-52-15
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-15-00-36-25
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-15-00-38-37
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-15-00-40-41
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-15-00-44-37
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-15-00-46-52
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-15-00-49-26
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-15-00-57-24
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-15-01-01-59
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2018-05-15-00-59-42
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-03-47-38
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-02-46-12
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-02-18-39
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-03-22-39
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-02-24-32
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-02-55-19
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-03-41-40
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-03-11-39
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-03-01-09
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-03-28-24
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-03-33-32
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-04-02-12
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-01-45-12
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-03-52-36
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-02-40-44
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-02-09-35
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-02-29-53
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-15-02-34-50
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-53-49
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-34-07
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-43-12
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-09-39
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-03-09-14
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-03-29-44
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-59-15
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-05-10
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-01-41-16
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-03-40-17
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-01-59-28
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-03-19-28
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-14-04
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-03-24-18
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-01-36-08
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-03-35-24
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-01-53-11
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-18-51
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-01-46-39
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-48-17
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-03-14-14
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-29-12
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-01-31-04
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-03-03-53
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-38-21
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-02-23-57
# Keypoint DB Processing:  /home/stanlew/src/kpam/data/logs_proto/2019-02-21-01-22-32
# Total number of images/keypoint entries is 70094

# %% [markdown]
# # Create Torch dataset from KeypointDB

# %%
kpLoaderConfig = KeypointDatasetConfig()
kpLoaderConfig.network_in_patch_width = 256
kpLoaderConfig.network_in_patch_height = 256
kpLoaderConfig.network_out_map_width = 64
kpLoaderConfig.network_out_map_height = 64
kpLoaderConfig.image_database_list.append(kpDb_train)
kpLoaderConfig.is_train = True

# %%
kpDatasetLoader_train = KeypointDataset(kpLoaderConfig)

# %% [markdown]
# # Construct the network itself

# %%
networkConfig = ResnetConfig()

networkConfig.num_keypoints = 3
networkConfig.image_channels = 4
networkConfig.depth_per_keypoint = 2
networkConfig.num_layers = 34

# %%
network = ResnetNoStage(networkConfig)
initialize_backbone_from_modelzoo(network.backbone_net, networkConfig.num_layers, networkConfig.image_channels)
network.cuda()
# Out:
# ResnetNoStage(
#   (backbone_net): ResNetBackbone(
#     (conv1): Conv2d(4, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (head_net): DeconvHead(
#     (features): ModuleList(
#       (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): ConvTranspose2d(256, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): ConvTranspose2d(256, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#       (9): Conv2d(256, 6, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %% [markdown]
# # Do Training

# %%
checkpoint_dir = "/home/stanlew/src/kpam/mankey_recreate/training_checkpoints_all_data"
if not os.path.exists(checkpoint_dir):
        os.mkdir(checkpoint_dir)

# %%
loader_train = DataLoader(dataset=kpDatasetLoader_train, batch_size=75, shuffle=True, num_workers=8)

learning_rate = 2e-4
n_epoch = 150

# %%
# The optimizer and scheduler
optimizer = torch.optim.Adam(network.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, [60, 90], gamma=0.1)

# %% [markdown]
# ### Training Loop

# %%
# The training loop
save_epoch_offset = 0
for epoch in range(n_epoch):
    epoch_start = time.time()
    batch_group_start = time.time()
    # Save the network
    if epoch % 5 == 0 and epoch > 0:
        file_name = 'checkpoint-%d.pth' % (epoch + save_epoch_offset)
        checkpoint_path = os.path.join(checkpoint_dir, file_name)
        print('Save the network at %s' % checkpoint_path)
        torch.save(network.state_dict(), checkpoint_path)
    # Prepare info for training
    network.train()
    train_error_xy = 0
    train_error_depth = 0
    
    # The learning rate step
    scheduler.step()
    for param_group in optimizer.param_groups:
        print('The learning rate is ', param_group['lr'])
    
    # The training iteration over the dataset
    for idx, data in enumerate(loader_train):
        # Get the data
        image = data[parameter.rgbd_image_key]
        keypoint_xy_depth = data[parameter.keypoint_xyd_key]
        keypoint_weight = data[parameter.keypoint_validity_key]

        # Upload to GPU
        image = image.cuda()
        keypoint_xy_depth = keypoint_xy_depth.cuda()
        keypoint_weight = keypoint_weight.cuda()

        # To predict
        optimizer.zero_grad()
        raw_pred = network(image)
        prob_pred = raw_pred[:, 0:networkConfig.num_keypoints, :, :]
        depthmap_pred = raw_pred[:, networkConfig.num_keypoints:, :, :]
        heatmap = predict.heatmap_from_predict(prob_pred, networkConfig.num_keypoints)
        _, _, heatmap_height, heatmap_width = heatmap.shape

        # Compute the coordinate
        coord_x, coord_y = predict.heatmap2d_to_normalized_imgcoord_gpu(heatmap, networkConfig.num_keypoints)
        depth_pred = predict.depth_integration(heatmap, depthmap_pred)

        # Concantate them
        xy_depth_pred = torch.cat((coord_x, coord_y, depth_pred), dim=2)

        # Compute loss
        loss = weighted_l1_loss(xy_depth_pred, keypoint_xy_depth, keypoint_weight)
        loss.backward()
        optimizer.step()

        # cleanup
        del loss

        # Log info
        xy_error = float(weighted_l1_loss(xy_depth_pred[:, :, 0:2], keypoint_xy_depth[:, :, 0:2], keypoint_weight[:, :, 0:2]).item())
        depth_error = float(weighted_l1_loss(xy_depth_pred[:, :, 2], keypoint_xy_depth[:, :, 2], keypoint_weight[:, :, 2]).item())
        if idx % 100 == 0:
            batch_group_end = time.time()
            print('Iteration %d in epoch %d' % (idx, epoch))
            print('The averaged pixel error is (pixel in 256x256 image): ', 256 * xy_error / len(xy_depth_pred))
            print('The averaged depth error is (mm): ', 256 * depth_error / len(xy_depth_pred))
            print('The elapsed time (s) was', batch_group_end - batch_group_start)
            batch_group_start = batch_group_end

        # Update info
        train_error_xy += float(xy_error)
        train_error_depth += float(depth_error)

    # The info at epoch level
    epoch_end = time.time()
    print('Epoch %d' % epoch)
    print('The training averaged pixel error is (pixel in 256x256 image): ', 256 * train_error_xy / len(kpDatasetLoader_train))
    print('The training averaged depth error is (mm): ', kpLoaderConfig.depth_image_scale * train_error_depth / len(kpDatasetLoader_train))
    print('The elapsed time (s) was', epoch_end - epoch_start)
# Out:
# The learning rate is  0.0002
# Iteration 0 in epoch 0
# The averaged pixel error is (pixel in 256x256 image):  3.192266031901042
# The averaged depth error is (mm):  5.7014778645833335
# The elapsed time (s) was 2.2210142612457275
# Iteration 100 in epoch 0
# The averaged pixel error is (pixel in 256x256 image):  3.3085723876953126
# The averaged depth error is (mm):  0.9506538899739584
# The elapsed time (s) was 60.10833930969238
# Iteration 200 in epoch 0
# The averaged pixel error is (pixel in 256x256 image):  3.32085693359375
# The averaged depth error is (mm):  1.1490675862630209
# The elapsed time (s) was 59.49474811553955
# Iteration 300 in epoch 0
# The averaged pixel error is (pixel in 256x256 image):  2.7718302408854165
# The averaged depth error is (mm):  1.037283223470052
# The elapsed time (s) was 58.28483533859253
# Iteration 400 in epoch 0
# The averaged pixel error is (pixel in 256x256 image):  2.5059112548828124
# The averaged depth error is (mm):  0.9591755167643229
# The elapsed time (s) was 58.44453978538513
# Iteration 500 in epoch 0
# The averaged pixel error is (pixel in 256x256 image):  2.188305460611979
# The averaged depth error is (mm):  1.7248649088541668
# The elapsed time (s) was 58.619099617004395
# Iteration 600 in epoch 0
# The averaged pixel error is (pixel in 256x256 image):  1.7377193196614584
# The averaged depth error is (mm):  1.3192714436848958
# The elapsed time (s) was 58.728065967559814
# Iteration 700 in epoch 0
# The averaged pixel error is (pixel in 256x256 image):  1.0052579752604167
# The averaged depth error is (mm):  0.9645536295572916
# The elapsed time (s) was 58.623311281204224
# Iteration 800 in epoch 0
# The averaged pixel error is (pixel in 256x256 image):  0.6397173563639323
# The averaged depth error is (mm):  0.8466224161783854
# The elapsed time (s) was 58.70854425430298
# Iteration 900 in epoch 0
# The averaged pixel error is (pixel in 256x256 image):  0.6482845560709636
# The averaged depth error is (mm):  1.062078145345052
# The elapsed time (s) was 58.84386706352234
# Epoch 0
# The training averaged pixel error is (pixel in 256x256 image):  2.1293108251107267
# The training averaged depth error is (mm):  1.1626048135829556
# The elapsed time (s) was 551.8728196620941
# The learning rate is  0.0002
# Iteration 0 in epoch 1
# The averaged pixel error is (pixel in 256x256 image):  0.6217473856608073
# The averaged depth error is (mm):  0.8479770914713541
# The elapsed time (s) was 2.2631351947784424
# Iteration 100 in epoch 1
# The averaged pixel error is (pixel in 256x256 image):  0.4922528584798177
# The averaged depth error is (mm):  0.5592072041829427
# The elapsed time (s) was 58.76016020774841
# Iteration 200 in epoch 1
# The averaged pixel error is (pixel in 256x256 image):  0.6006436157226562
# The averaged depth error is (mm):  1.8420652262369792
# The elapsed time (s) was 58.84628510475159
# Iteration 300 in epoch 1
# The averaged pixel error is (pixel in 256x256 image):  0.46751063028971357
# The averaged depth error is (mm):  1.019772440592448
# The elapsed time (s) was 58.78761696815491
# Iteration 400 in epoch 1
# The averaged pixel error is (pixel in 256x256 image):  0.5023647054036459
# The averaged depth error is (mm):  0.7558946228027343
# The elapsed time (s) was 58.80998873710632
# Iteration 500 in epoch 1
# The averaged pixel error is (pixel in 256x256 image):  0.5142735799153646
# The averaged depth error is (mm):  0.5684654744466145
# The elapsed time (s) was 58.76406955718994
# Iteration 600 in epoch 1
# The averaged pixel error is (pixel in 256x256 image):  0.4227573394775391
# The averaged depth error is (mm):  0.7219715372721354
# The elapsed time (s) was 58.80388522148132
# Iteration 700 in epoch 1
# The averaged pixel error is (pixel in 256x256 image):  0.4641887410481771
# The averaged depth error is (mm):  1.093012186686198
# The elapsed time (s) was 58.786967515945435
# Iteration 800 in epoch 1
# The averaged pixel error is (pixel in 256x256 image):  0.4329515075683594
# The averaged depth error is (mm):  0.7345378621419271
# The elapsed time (s) was 58.83066153526306
# Iteration 900 in epoch 1
# The averaged pixel error is (pixel in 256x256 image):  0.3841742706298828
# The averaged depth error is (mm):  0.4779590352376302
# The elapsed time (s) was 58.80749702453613
# Epoch 1
# The training averaged pixel error is (pixel in 256x256 image):  0.48409341303881187
# The training averaged depth error is (mm):  0.6811804768021927
# The elapsed time (s) was 551.2773923873901
# The learning rate is  0.0002
# Iteration 0 in epoch 2
# The averaged pixel error is (pixel in 256x256 image):  0.34644142150878904
# The averaged depth error is (mm):  0.7682981872558594
# The elapsed time (s) was 2.405106782913208
# Iteration 100 in epoch 2
# The averaged pixel error is (pixel in 256x256 image):  0.3405451456705729
# The averaged depth error is (mm):  0.4812317403157552
# The elapsed time (s) was 59.2156708240509
# Iteration 200 in epoch 2
# The averaged pixel error is (pixel in 256x256 image):  0.32625012715657553
# The averaged depth error is (mm):  0.418511479695638
# The elapsed time (s) was 58.883965492248535
# Iteration 300 in epoch 2
# The averaged pixel error is (pixel in 256x256 image):  0.35234870910644533
# The averaged depth error is (mm):  0.41649398803710935
# The elapsed time (s) was 58.863057136535645
# Iteration 400 in epoch 2
# The averaged pixel error is (pixel in 256x256 image):  0.38803680419921877
# The averaged depth error is (mm):  0.5986750793457031
# The elapsed time (s) was 58.81693124771118
# Iteration 500 in epoch 2
# The averaged pixel error is (pixel in 256x256 image):  0.35357076009114585
# The averaged depth error is (mm):  0.7786882019042969
# The elapsed time (s) was 58.86739683151245
# Iteration 600 in epoch 2
# The averaged pixel error is (pixel in 256x256 image):  0.36304641723632813
# The averaged depth error is (mm):  0.5284170023600261
# The elapsed time (s) was 58.77626323699951
# Iteration 700 in epoch 2
# The averaged pixel error is (pixel in 256x256 image):  0.30685577392578123
# The averaged depth error is (mm):  0.6590052286783854
# The elapsed time (s) was 59.001991748809814
# Iteration 800 in epoch 2
# The averaged pixel error is (pixel in 256x256 image):  0.3034807840983073
# The averaged depth error is (mm):  0.7751866658528646
# The elapsed time (s) was 58.76325178146362
# Iteration 900 in epoch 2
# The averaged pixel error is (pixel in 256x256 image):  0.3301373545328776
# The averaged depth error is (mm):  0.46066635131835937
# The elapsed time (s) was 58.938565492630005
# Epoch 2
# The training averaged pixel error is (pixel in 256x256 image):  0.3453260279111312
# The training averaged depth error is (mm):  0.5603654043859574
# The elapsed time (s) was 552.3290784358978
# The learning rate is  0.0002
# Iteration 0 in epoch 3
# The averaged pixel error is (pixel in 256x256 image):  0.3242980702718099
# The averaged depth error is (mm):  0.39817891438802083
# The elapsed time (s) was 2.2438549995422363
# Iteration 100 in epoch 3
# The averaged pixel error is (pixel in 256x256 image):  0.4838861083984375
# The averaged depth error is (mm):  0.5029453023274739
# The elapsed time (s) was 58.86936712265015
# Iteration 200 in epoch 3
# The averaged pixel error is (pixel in 256x256 image):  0.28399592081705727
# The averaged depth error is (mm):  0.8119285074869792
# The elapsed time (s) was 58.8885600566864
# Iteration 300 in epoch 3
# The averaged pixel error is (pixel in 256x256 image):  0.2958458964029948
# The averaged depth error is (mm):  0.3227562204996745
# The elapsed time (s) was 58.87372708320618
# Iteration 400 in epoch 3
# The averaged pixel error is (pixel in 256x256 image):  0.28435890197753905
# The averaged depth error is (mm):  0.5941621398925782
# The elapsed time (s) was 58.90910196304321
# Iteration 500 in epoch 3
# The averaged pixel error is (pixel in 256x256 image):  0.3527943166097005
# The averaged depth error is (mm):  0.6237397766113282
# The elapsed time (s) was 58.796183347702026
# Iteration 600 in epoch 3
# The averaged pixel error is (pixel in 256x256 image):  0.2582482147216797
# The averaged depth error is (mm):  0.33021759033203124
# The elapsed time (s) was 58.93919086456299
# Iteration 700 in epoch 3
# The averaged pixel error is (pixel in 256x256 image):  0.26908304850260417
# The averaged depth error is (mm):  0.5186451721191406
# The elapsed time (s) was 59.24261021614075
# Iteration 800 in epoch 3
# The averaged pixel error is (pixel in 256x256 image):  0.2911034393310547
# The averaged depth error is (mm):  0.5856694539388021
# The elapsed time (s) was 58.971867084503174
# Iteration 900 in epoch 3
# The averaged pixel error is (pixel in 256x256 image):  0.31867393493652346
# The averaged depth error is (mm):  0.3266970825195312
# The elapsed time (s) was 58.90319561958313
# Epoch 3
# The training averaged pixel error is (pixel in 256x256 image):  0.2991647576389154
# The training averaged depth error is (mm):  0.4997801759884042
# The elapsed time (s) was 552.5336124897003
# The learning rate is  0.0002
# Iteration 0 in epoch 4
# The averaged pixel error is (pixel in 256x256 image):  0.2683899943033854
# The averaged depth error is (mm):  0.31942100524902345
# The elapsed time (s) was 2.1054158210754395
# Iteration 100 in epoch 4
# The averaged pixel error is (pixel in 256x256 image):  0.24910985310872397
# The averaged depth error is (mm):  0.42749547322591147
# The elapsed time (s) was 58.8888578414917
# Iteration 200 in epoch 4
# The averaged pixel error is (pixel in 256x256 image):  0.273454844156901
# The averaged depth error is (mm):  0.3869790903727214
# The elapsed time (s) was 58.77086591720581
# Iteration 300 in epoch 4
# The averaged pixel error is (pixel in 256x256 image):  0.25876091003417967
# The averaged depth error is (mm):  0.46238871256510417
# The elapsed time (s) was 58.73548460006714
# Iteration 400 in epoch 4
# The averaged pixel error is (pixel in 256x256 image):  0.280706303914388
# The averaged depth error is (mm):  0.5021852620442708
# The elapsed time (s) was 58.99502348899841
# Iteration 500 in epoch 4
# The averaged pixel error is (pixel in 256x256 image):  0.27074432373046875
# The averaged depth error is (mm):  0.4501880391438802
# The elapsed time (s) was 59.45914626121521
# Iteration 600 in epoch 4
# The averaged pixel error is (pixel in 256x256 image):  0.2826600138346354
# The averaged depth error is (mm):  0.4645386250813802
# The elapsed time (s) was 58.88977789878845
# Iteration 700 in epoch 4
# The averaged pixel error is (pixel in 256x256 image):  0.3084278106689453
# The averaged depth error is (mm):  0.5253488159179688
# The elapsed time (s) was 58.90142035484314
# Iteration 800 in epoch 4
# The averaged pixel error is (pixel in 256x256 image):  0.24504788716634116
# The averaged depth error is (mm):  0.3482492828369141
# The elapsed time (s) was 58.83175539970398
# Iteration 900 in epoch 4
# The averaged pixel error is (pixel in 256x256 image):  0.26139498392740884
# The averaged depth error is (mm):  0.31517552693684897
# The elapsed time (s) was 58.86856985092163
# Epoch 4
# The training averaged pixel error is (pixel in 256x256 image):  0.2664881239645688
# The training averaged depth error is (mm):  0.4455921734628022
# The elapsed time (s) was 552.2561888694763
# Save the network at /home/stanlew/src/kpam/mankey_recreate/training_checkpoints_all_data/checkpoint-5.pth
# The learning rate is  0.0002
# Iteration 0 in epoch 5
# The averaged pixel error is (pixel in 256x256 image):  0.23329068501790365
# The averaged depth error is (mm):  0.3330236307779948
# The elapsed time (s) was 2.479027509689331
# Iteration 100 in epoch 5
# The averaged pixel error is (pixel in 256x256 image):  0.224627685546875
# The averaged depth error is (mm):  0.23822947184244792
# The elapsed time (s) was 58.87925052642822
# Iteration 200 in epoch 5
# The averaged pixel error is (pixel in 256x256 image):  0.34382530212402346
# The averaged depth error is (mm):  0.5218309020996094
# The elapsed time (s) was 58.771984815597534
# Iteration 300 in epoch 5
# The averaged pixel error is (pixel in 256x256 image):  0.22273183186848958
# The averaged depth error is (mm):  0.6906806945800781
# The elapsed time (s) was 58.88949203491211
# Iteration 400 in epoch 5
# The averaged pixel error is (pixel in 256x256 image):  0.23952428181966146
# The averaged depth error is (mm):  0.48389404296875
# The elapsed time (s) was 58.88111615180969
# Iteration 500 in epoch 5
# The averaged pixel error is (pixel in 256x256 image):  0.2675442250569661
# The averaged depth error is (mm):  0.47562596638997395
# The elapsed time (s) was 58.82656216621399
# Iteration 600 in epoch 5
# The averaged pixel error is (pixel in 256x256 image):  0.22614161173502603
# The averaged depth error is (mm):  0.5552883911132812
# The elapsed time (s) was 58.83209729194641
# Iteration 700 in epoch 5
# The averaged pixel error is (pixel in 256x256 image):  0.2534315490722656
# The averaged depth error is (mm):  0.35129417419433595
# The elapsed time (s) was 58.96613359451294
# Iteration 800 in epoch 5
# The averaged pixel error is (pixel in 256x256 image):  0.24194714864095052
# The averaged depth error is (mm):  0.39575520833333333
# The elapsed time (s) was 58.87623429298401
# Iteration 900 in epoch 5
# The averaged pixel error is (pixel in 256x256 image):  0.25212842305501304
# The averaged depth error is (mm):  0.32939440409342446
# The elapsed time (s) was 58.87867307662964
# Epoch 5
# The training averaged pixel error is (pixel in 256x256 image):  0.24306477349872585
# The training averaged depth error is (mm):  0.4092915695492584
# The elapsed time (s) was 552.0870804786682
# The learning rate is  0.0002
# Iteration 0 in epoch 6
# The averaged pixel error is (pixel in 256x256 image):  0.2357587178548177
# The averaged depth error is (mm):  0.42215967814127603
# The elapsed time (s) was 2.2241392135620117
# Iteration 100 in epoch 6
# The averaged pixel error is (pixel in 256x256 image):  0.21468360900878905
# The averaged depth error is (mm):  0.23436144510904947
# The elapsed time (s) was 58.83790683746338
# Iteration 200 in epoch 6
# The averaged pixel error is (pixel in 256x256 image):  0.2250529988606771
# The averaged depth error is (mm):  0.27579142252604166
# The elapsed time (s) was 58.841367959976196
# Iteration 300 in epoch 6
# The averaged pixel error is (pixel in 256x256 image):  0.22338091532389323
# The averaged depth error is (mm):  0.3260544840494792
# The elapsed time (s) was 58.83808732032776
# Iteration 400 in epoch 6
# The averaged pixel error is (pixel in 256x256 image):  0.3369740041097005
# The averaged depth error is (mm):  0.29893183390299477
# The elapsed time (s) was 58.814311504364014
# Iteration 500 in epoch 6
# The averaged pixel error is (pixel in 256x256 image):  0.21226346333821614
# The averaged depth error is (mm):  0.3178265889485677
# The elapsed time (s) was 58.76237940788269
# Iteration 600 in epoch 6
# The averaged pixel error is (pixel in 256x256 image):  0.22543917338053385
# The averaged depth error is (mm):  0.2852088165283203
# The elapsed time (s) was 58.82517766952515
# Iteration 700 in epoch 6
# The averaged pixel error is (pixel in 256x256 image):  0.2404621124267578
# The averaged depth error is (mm):  0.40822293599446613
# The elapsed time (s) was 58.80339574813843
# Iteration 800 in epoch 6
# The averaged pixel error is (pixel in 256x256 image):  0.2195794423421224
# The averaged depth error is (mm):  0.3542156982421875
# The elapsed time (s) was 58.827359437942505
# Iteration 900 in epoch 6
# The averaged pixel error is (pixel in 256x256 image):  0.2088549550374349
# The averaged depth error is (mm):  0.3164891306559245
# The elapsed time (s) was 58.8403537273407
# Epoch 6
# The training averaged pixel error is (pixel in 256x256 image):  0.2281307073436348
# The training averaged depth error is (mm):  0.3797619750497208
# The elapsed time (s) was 551.4220893383026
# The learning rate is  0.0002
# Iteration 0 in epoch 7
# The averaged pixel error is (pixel in 256x256 image):  0.21571940104166668
# The averaged depth error is (mm):  0.28216217041015623
# The elapsed time (s) was 2.3789970874786377
# Iteration 100 in epoch 7
# The averaged pixel error is (pixel in 256x256 image):  0.22105377197265624
# The averaged depth error is (mm):  0.2792008209228516
# The elapsed time (s) was 58.8555006980896
# Iteration 200 in epoch 7
# The averaged pixel error is (pixel in 256x256 image):  0.22218790690104168
# The averaged depth error is (mm):  0.30594327290852863
# The elapsed time (s) was 58.800538063049316
# Iteration 300 in epoch 7
# The averaged pixel error is (pixel in 256x256 image):  0.21313138326009115
# The averaged depth error is (mm):  0.32270179748535155
# The elapsed time (s) was 58.89350342750549
# Iteration 400 in epoch 7
# The averaged pixel error is (pixel in 256x256 image):  0.23665509541829427
# The averaged depth error is (mm):  0.2989852142333984
# The elapsed time (s) was 58.9340603351593
# Iteration 500 in epoch 7
# The averaged pixel error is (pixel in 256x256 image):  0.19753269195556641
# The averaged depth error is (mm):  0.3308424377441406
# The elapsed time (s) was 59.154855728149414
# Iteration 600 in epoch 7
# The averaged pixel error is (pixel in 256x256 image):  0.20582252502441406
# The averaged depth error is (mm):  0.42498769124348956
# The elapsed time (s) was 58.90726613998413
# Iteration 700 in epoch 7
# The averaged pixel error is (pixel in 256x256 image):  0.21555013020833333
# The averaged depth error is (mm):  0.23794031778971353
# The elapsed time (s) was 59.01085162162781
# Iteration 800 in epoch 7
# The averaged pixel error is (pixel in 256x256 image):  0.20714502970377605
# The averaged depth error is (mm):  0.7081560262044271
# The elapsed time (s) was 58.99870562553406
# Iteration 900 in epoch 7
# The averaged pixel error is (pixel in 256x256 image):  0.2158160909016927
# The averaged depth error is (mm):  0.49780609130859377
# The elapsed time (s) was 58.90418553352356
# Epoch 7
# The training averaged pixel error is (pixel in 256x256 image):  0.21295129325273057
# The training averaged depth error is (mm):  0.348646582735892
# The elapsed time (s) was 552.6099033355713
# The learning rate is  0.0002
# Iteration 0 in epoch 8
# The averaged pixel error is (pixel in 256x256 image):  0.21393536885579428
# The averaged depth error is (mm):  0.2730130767822266
# The elapsed time (s) was 2.134676933288574
# Iteration 100 in epoch 8
# The averaged pixel error is (pixel in 256x256 image):  0.21782742818196615
# The averaged depth error is (mm):  0.3148826344807943
# The elapsed time (s) was 58.90314483642578
# Iteration 200 in epoch 8
# The averaged pixel error is (pixel in 256x256 image):  0.19489818572998047
# The averaged depth error is (mm):  0.2545074208577474
# The elapsed time (s) was 58.86535167694092
# Iteration 300 in epoch 8
# The averaged pixel error is (pixel in 256x256 image):  0.22366236368815104
# The averaged depth error is (mm):  0.3277996063232422
# The elapsed time (s) was 58.91851544380188
# Iteration 400 in epoch 8
# The averaged pixel error is (pixel in 256x256 image):  0.21985687255859376
# The averaged depth error is (mm):  0.31517283121744794
# The elapsed time (s) was 58.810577392578125
# Iteration 500 in epoch 8
# The averaged pixel error is (pixel in 256x256 image):  0.21434361775716146
# The averaged depth error is (mm):  0.3305277760823568
# The elapsed time (s) was 58.87631130218506
# Iteration 600 in epoch 8
# The averaged pixel error is (pixel in 256x256 image):  0.20123685201009114
# The averaged depth error is (mm):  0.288643544514974
# The elapsed time (s) was 58.84713292121887
# Iteration 700 in epoch 8
# The averaged pixel error is (pixel in 256x256 image):  0.2360309600830078
# The averaged depth error is (mm):  0.2667857615152995
# The elapsed time (s) was 58.97730541229248
# Iteration 800 in epoch 8
# The averaged pixel error is (pixel in 256x256 image):  0.1992339833577474
# The averaged depth error is (mm):  0.24075642903645833
# The elapsed time (s) was 59.031846046447754
# Iteration 900 in epoch 8
# The averaged pixel error is (pixel in 256x256 image):  0.2088440195719401
# The averaged depth error is (mm):  0.3628004964192708
# The elapsed time (s) was 58.962607622146606
# Epoch 8
# The training averaged pixel error is (pixel in 256x256 image):  0.20347867238013745
# The training averaged depth error is (mm):  0.3235073559266591
# The elapsed time (s) was 552.214076757431
# The learning rate is  0.0002
# Iteration 0 in epoch 9
# The averaged pixel error is (pixel in 256x256 image):  0.2027524948120117
# The averaged depth error is (mm):  0.3051835123697917
# The elapsed time (s) was 2.528557300567627
# Iteration 100 in epoch 9
# The averaged pixel error is (pixel in 256x256 image):  0.2165570068359375
# The averaged depth error is (mm):  0.28020795186360675
# The elapsed time (s) was 58.89921522140503
# Iteration 200 in epoch 9
# The averaged pixel error is (pixel in 256x256 image):  0.1869176228841146
# The averaged depth error is (mm):  0.22766647338867188
# The elapsed time (s) was 59.04111123085022
# Iteration 300 in epoch 9
# The averaged pixel error is (pixel in 256x256 image):  0.17859002431233725
# The averaged depth error is (mm):  0.23711158752441405
# The elapsed time (s) was 59.07135558128357
# Iteration 400 in epoch 9
# The averaged pixel error is (pixel in 256x256 image):  0.182701784769694
# The averaged depth error is (mm):  0.23176661173502605
# The elapsed time (s) was 59.20240879058838
# Iteration 500 in epoch 9
# The averaged pixel error is (pixel in 256x256 image):  0.19101539611816407
# The averaged depth error is (mm):  0.25719228108723957
# The elapsed time (s) was 59.21267485618591
# Iteration 600 in epoch 9
# The averaged pixel error is (pixel in 256x256 image):  0.1923512649536133
# The averaged depth error is (mm):  0.2152814483642578
# The elapsed time (s) was 59.42661809921265
# Iteration 700 in epoch 9
# The averaged pixel error is (pixel in 256x256 image):  0.20201029459635417
# The averaged depth error is (mm):  0.20186927795410156
# The elapsed time (s) was 59.42960214614868
# Iteration 800 in epoch 9
# The averaged pixel error is (pixel in 256x256 image):  0.17723798116048178
# The averaged depth error is (mm):  0.21646135965983074
# The elapsed time (s) was 59.43727469444275
# Iteration 900 in epoch 9
# The averaged pixel error is (pixel in 256x256 image):  0.23862833658854166
# The averaged depth error is (mm):  0.33842325846354165
# The elapsed time (s) was 59.35978698730469
# Epoch 9
# The training averaged pixel error is (pixel in 256x256 image):  0.190391257869999
# The training averaged depth error is (mm):  0.29102172520128905
# The elapsed time (s) was 555.5724031925201
# Save the network at /home/stanlew/src/kpam/mankey_recreate/training_checkpoints_all_data/checkpoint-10.pth
# The learning rate is  0.0002
# Iteration 0 in epoch 10
# The averaged pixel error is (pixel in 256x256 image):  0.17565221150716145
# The averaged depth error is (mm):  0.20224540710449218
# The elapsed time (s) was 2.63206148147583
# Iteration 100 in epoch 10
# The averaged pixel error is (pixel in 256x256 image):  0.16553722381591796
# The averaged depth error is (mm):  0.27605812072753905
# The elapsed time (s) was 59.424214124679565
# Iteration 200 in epoch 10
# The averaged pixel error is (pixel in 256x256 image):  0.16760733286539714
# The averaged depth error is (mm):  0.22318997701009113
# The elapsed time (s) was 59.25893187522888
# Iteration 300 in epoch 10
# The averaged pixel error is (pixel in 256x256 image):  0.18007935841878256
# The averaged depth error is (mm):  0.27141894022623697
# The elapsed time (s) was 59.293891191482544
# Iteration 400 in epoch 10
# The averaged pixel error is (pixel in 256x256 image):  0.16404722849527995
# The averaged depth error is (mm):  0.15454086303710937
# The elapsed time (s) was 59.237061738967896
# Iteration 500 in epoch 10
# The averaged pixel error is (pixel in 256x256 image):  0.17462586720784506
# The averaged depth error is (mm):  0.24908673604329426
# The elapsed time (s) was 59.39843702316284
# Iteration 600 in epoch 10
# The averaged pixel error is (pixel in 256x256 image):  0.19222240447998046
# The averaged depth error is (mm):  0.4559264119466146
# The elapsed time (s) was 59.196544885635376
# Iteration 700 in epoch 10
# The averaged pixel error is (pixel in 256x256 image):  0.18396876017252603
# The averaged depth error is (mm):  0.1686025365193685
# The elapsed time (s) was 59.24592900276184
# Iteration 800 in epoch 10
# The averaged pixel error is (pixel in 256x256 image):  0.16806809743245443
# The averaged depth error is (mm):  0.2864611053466797
# The elapsed time (s) was 59.20751714706421
# Iteration 900 in epoch 10
# The averaged pixel error is (pixel in 256x256 image):  0.17515135447184244
# The averaged depth error is (mm):  0.28836372375488284
# The elapsed time (s) was 59.26597571372986
# Epoch 10
# The training averaged pixel error is (pixel in 256x256 image):  0.1827044754622615
# The training averaged depth error is (mm):  0.2890932481666535
# The elapsed time (s) was 556.0495774745941
# The learning rate is  0.0002
# Iteration 0 in epoch 11
# The averaged pixel error is (pixel in 256x256 image):  0.18260052998860676
# The averaged depth error is (mm):  0.3296155039469401
# The elapsed time (s) was 2.1328446865081787
# Iteration 100 in epoch 11
# The averaged pixel error is (pixel in 256x256 image):  0.17299545288085938
# The averaged depth error is (mm):  0.26392473856608073
# The elapsed time (s) was 59.236382246017456
# Iteration 200 in epoch 11
# The averaged pixel error is (pixel in 256x256 image):  0.1723098627726237
# The averaged depth error is (mm):  0.33983983357747394
# The elapsed time (s) was 59.134504079818726
# Iteration 300 in epoch 11
# The averaged pixel error is (pixel in 256x256 image):  0.18248645782470704
# The averaged depth error is (mm):  0.3551942443847656
# The elapsed time (s) was 59.14851713180542
# Iteration 400 in epoch 11
# The averaged pixel error is (pixel in 256x256 image):  0.17204063415527343
# The averaged depth error is (mm):  0.18816028594970702
# The elapsed time (s) was 59.240461111068726
# Iteration 500 in epoch 11
# The averaged pixel error is (pixel in 256x256 image):  0.1824655024210612
# The averaged depth error is (mm):  0.37037022908528644
# The elapsed time (s) was 59.15394401550293
# Iteration 600 in epoch 11
# The averaged pixel error is (pixel in 256x256 image):  0.16795496622721354
# The averaged depth error is (mm):  0.21904769897460938
# The elapsed time (s) was 59.283533811569214
# Iteration 700 in epoch 11
# The averaged pixel error is (pixel in 256x256 image):  0.15825443267822265
# The averaged depth error is (mm):  0.2606464131673177
# The elapsed time (s) was 59.0310480594635
# Iteration 800 in epoch 11
# The averaged pixel error is (pixel in 256x256 image):  0.17284523010253905
# The averaged depth error is (mm):  0.2701220194498698
# The elapsed time (s) was 59.13889408111572
# Iteration 900 in epoch 11
# The averaged pixel error is (pixel in 256x256 image):  0.16132726033528647
# The averaged depth error is (mm):  0.2487944793701172
# The elapsed time (s) was 59.0566565990448
# Epoch 11
# The training averaged pixel error is (pixel in 256x256 image):  0.17457876404903142
# The training averaged depth error is (mm):  0.2692055319754697
# The elapsed time (s) was 554.4865846633911
# The learning rate is  0.0002
# Iteration 0 in epoch 12
# The averaged pixel error is (pixel in 256x256 image):  0.167647705078125
# The averaged depth error is (mm):  0.2236327107747396
# The elapsed time (s) was 2.6131694316864014
# Iteration 100 in epoch 12
# The averaged pixel error is (pixel in 256x256 image):  0.16036290486653645
# The averaged depth error is (mm):  0.1923269780476888
# The elapsed time (s) was 59.06043028831482
# Iteration 200 in epoch 12
# The averaged pixel error is (pixel in 256x256 image):  0.1631845219930013
# The averaged depth error is (mm):  0.22448577880859374
# The elapsed time (s) was 59.214447259902954
# Iteration 300 in epoch 12
# The averaged pixel error is (pixel in 256x256 image):  0.16517990112304687
# The averaged depth error is (mm):  0.30385986328125
# The elapsed time (s) was 59.023436069488525
# Iteration 400 in epoch 12
# The averaged pixel error is (pixel in 256x256 image):  0.15994444529215496
# The averaged depth error is (mm):  0.2986194610595703
# The elapsed time (s) was 59.172823667526245
# Iteration 500 in epoch 12
# The averaged pixel error is (pixel in 256x256 image):  0.18894878387451172
# The averaged depth error is (mm):  0.273180185953776
# The elapsed time (s) was 59.083422899246216
# Iteration 600 in epoch 12
# The averaged pixel error is (pixel in 256x256 image):  0.1678771718343099
# The averaged depth error is (mm):  0.19207029978434245
# The elapsed time (s) was 59.204270362854004
# Iteration 700 in epoch 12
# The averaged pixel error is (pixel in 256x256 image):  0.1912066904703776
# The averaged depth error is (mm):  0.17677925109863282
# The elapsed time (s) was 59.102264165878296
# Iteration 800 in epoch 12
# The averaged pixel error is (pixel in 256x256 image):  0.1751401901245117
# The averaged depth error is (mm):  0.21800425211588542
# The elapsed time (s) was 59.12929916381836
# Iteration 900 in epoch 12
# The averaged pixel error is (pixel in 256x256 image):  0.20004117329915364
# The averaged depth error is (mm):  0.26196744283040363
# The elapsed time (s) was 59.05556559562683
# Epoch 12
# The training averaged pixel error is (pixel in 256x256 image):  0.17148268668053682
# The training averaged depth error is (mm):  0.26471359680038203
# The elapsed time (s) was 554.5052542686462
# The learning rate is  0.0002
# Iteration 0 in epoch 13
# The averaged pixel error is (pixel in 256x256 image):  0.17715057373046875
# The averaged depth error is (mm):  0.2697878265380859
# The elapsed time (s) was 2.284954071044922
# Iteration 100 in epoch 13
# The averaged pixel error is (pixel in 256x256 image):  0.1553030522664388
# The averaged depth error is (mm):  0.3350946044921875
# The elapsed time (s) was 59.13825559616089
# Iteration 200 in epoch 13
# The averaged pixel error is (pixel in 256x256 image):  0.1637539545694987
# The averaged depth error is (mm):  0.19184576670328776
# The elapsed time (s) was 59.09845471382141
# Iteration 300 in epoch 13
# The averaged pixel error is (pixel in 256x256 image):  0.14427762349446616
# The averaged depth error is (mm):  0.23611401875813803
# The elapsed time (s) was 59.0653235912323
# Iteration 400 in epoch 13
# The averaged pixel error is (pixel in 256x256 image):  0.151909917195638
# The averaged depth error is (mm):  0.22041277567545572
# The elapsed time (s) was 59.05485129356384
# Iteration 500 in epoch 13
# The averaged pixel error is (pixel in 256x256 image):  0.16943620045979818
# The averaged depth error is (mm):  0.21257157643636068
# The elapsed time (s) was 59.1576828956604
# Iteration 600 in epoch 13
# The averaged pixel error is (pixel in 256x256 image):  0.1520465850830078
# The averaged depth error is (mm):  0.22403251647949218
# The elapsed time (s) was 58.93964719772339
# Iteration 700 in epoch 13
# The averaged pixel error is (pixel in 256x256 image):  0.17096519470214844
# The averaged depth error is (mm):  0.3556255849202474
# The elapsed time (s) was 59.11802697181702
# Iteration 800 in epoch 13
# The averaged pixel error is (pixel in 256x256 image):  0.15322731018066407
# The averaged depth error is (mm):  0.16700425465901692
# The elapsed time (s) was 59.073421478271484
# Iteration 900 in epoch 13
# The averaged pixel error is (pixel in 256x256 image):  0.17963605244954428
# The averaged depth error is (mm):  0.27063329060872393
# The elapsed time (s) was 59.11844611167908
# Epoch 13
# The training averaged pixel error is (pixel in 256x256 image):  0.1636060055854552
# The training averaged depth error is (mm):  0.25361069543938475
# The elapsed time (s) was 553.9025309085846
# The learning rate is  0.0002
# Iteration 0 in epoch 14
# The averaged pixel error is (pixel in 256x256 image):  0.16854076385498046
# The averaged depth error is (mm):  0.24406333923339843
# The elapsed time (s) was 2.153144598007202
# Iteration 100 in epoch 14
# The averaged pixel error is (pixel in 256x256 image):  0.15274031321207682
# The averaged depth error is (mm):  0.22451817830403645
# The elapsed time (s) was 58.96981191635132
# Iteration 200 in epoch 14
# The averaged pixel error is (pixel in 256x256 image):  0.18162372589111328
# The averaged depth error is (mm):  0.2089263916015625
# The elapsed time (s) was 59.03789663314819
# Iteration 300 in epoch 14
# The averaged pixel error is (pixel in 256x256 image):  0.1698698933919271
# The averaged depth error is (mm):  0.2996537780761719
# The elapsed time (s) was 59.00852942466736
# Iteration 400 in epoch 14
# The averaged pixel error is (pixel in 256x256 image):  0.14809710184733074
# The averaged depth error is (mm):  0.20197467803955077
# The elapsed time (s) was 59.16406846046448
# Iteration 500 in epoch 14
# The averaged pixel error is (pixel in 256x256 image):  0.17961775461832682
# The averaged depth error is (mm):  0.22086669921875
# The elapsed time (s) was 59.10123682022095
# Iteration 600 in epoch 14
# The averaged pixel error is (pixel in 256x256 image):  0.1555297597249349
# The averaged depth error is (mm):  0.2698652903238932
# The elapsed time (s) was 59.12628126144409
# Iteration 700 in epoch 14
# The averaged pixel error is (pixel in 256x256 image):  0.17230906168619792
# The averaged depth error is (mm):  0.25670756022135416
# The elapsed time (s) was 59.1126971244812
# Iteration 800 in epoch 14
# The averaged pixel error is (pixel in 256x256 image):  0.18105037689208983
# The averaged depth error is (mm):  0.3034660339355469
# The elapsed time (s) was 59.09813976287842
# Iteration 900 in epoch 14
# The averaged pixel error is (pixel in 256x256 image):  0.17221441904703777
# The averaged depth error is (mm):  0.165691769917806
# The elapsed time (s) was 59.134705781936646
# Epoch 14
# The training averaged pixel error is (pixel in 256x256 image):  0.1608666527794068
# The training averaged depth error is (mm):  0.2484157863729816
# The elapsed time (s) was 553.757651090622
# Save the network at /home/stanlew/src/kpam/mankey_recreate/training_checkpoints_all_data/checkpoint-15.pth
# The learning rate is  0.0002
# Iteration 0 in epoch 15
# The averaged pixel error is (pixel in 256x256 image):  0.15106178283691407
# The averaged depth error is (mm):  0.1926078160603841
# The elapsed time (s) was 2.657151699066162
# Iteration 100 in epoch 15
# The averaged pixel error is (pixel in 256x256 image):  0.16619827270507812
# The averaged depth error is (mm):  0.2759513854980469
# The elapsed time (s) was 59.020095109939575
# Iteration 200 in epoch 15
# The averaged pixel error is (pixel in 256x256 image):  0.14874347686767578
# The averaged depth error is (mm):  0.2638958485921224
# The elapsed time (s) was 59.114017486572266
# Iteration 300 in epoch 15
# The averaged pixel error is (pixel in 256x256 image):  0.15418988545735676
# The averaged depth error is (mm):  0.16060094197591146
# The elapsed time (s) was 59.238242626190186
# Iteration 400 in epoch 15
# The averaged pixel error is (pixel in 256x256 image):  0.15215469360351563
# The averaged depth error is (mm):  0.43608047485351564
# The elapsed time (s) was 58.98280692100525
# Iteration 500 in epoch 15
# The averaged pixel error is (pixel in 256x256 image):  0.16236118316650391
# The averaged depth error is (mm):  0.16738174438476563
# The elapsed time (s) was 59.08726358413696
# Iteration 600 in epoch 15
# The averaged pixel error is (pixel in 256x256 image):  0.1608413823445638
# The averaged depth error is (mm):  0.403393809000651
# The elapsed time (s) was 59.034305572509766
# Iteration 700 in epoch 15
# The averaged pixel error is (pixel in 256x256 image):  0.1419617462158203
# The averaged depth error is (mm):  0.2003393300374349
# The elapsed time (s) was 59.184460401535034
# Iteration 800 in epoch 15
# The averaged pixel error is (pixel in 256x256 image):  0.16707377115885416
# The averaged depth error is (mm):  0.2596703084309896
# The elapsed time (s) was 59.15798997879028
# Iteration 900 in epoch 15
# The averaged pixel error is (pixel in 256x256 image):  0.1531868362426758
# The averaged depth error is (mm):  0.245020268758138
# The elapsed time (s) was 59.12320303916931
# Epoch 15
# The training averaged pixel error is (pixel in 256x256 image):  0.15317940610613018
# The training averaged depth error is (mm):  0.2365631749294119
# The elapsed time (s) was 554.4476680755615
# The learning rate is  0.0002
# Iteration 0 in epoch 16
# The averaged pixel error is (pixel in 256x256 image):  0.15109525044759115
# The averaged depth error is (mm):  0.4278112284342448
# The elapsed time (s) was 2.641852617263794
# Iteration 100 in epoch 16
# The averaged pixel error is (pixel in 256x256 image):  0.12675167083740235
# The averaged depth error is (mm):  0.2784698486328125
# The elapsed time (s) was 58.93621206283569
# Iteration 200 in epoch 16
# The averaged pixel error is (pixel in 256x256 image):  0.1508856964111328
# The averaged depth error is (mm):  0.167701416015625
# The elapsed time (s) was 59.03189182281494
# Iteration 300 in epoch 16
# The averaged pixel error is (pixel in 256x256 image):  0.14515446980794272
# The averaged depth error is (mm):  0.22075294494628905
# The elapsed time (s) was 59.036840200424194
# Iteration 400 in epoch 16
# The averaged pixel error is (pixel in 256x256 image):  0.14816816965738933
# The averaged depth error is (mm):  0.20013790130615233
# The elapsed time (s) was 59.041518211364746
# Iteration 500 in epoch 16
# The averaged pixel error is (pixel in 256x256 image):  0.15860313415527344
# The averaged depth error is (mm):  0.24419921875
# The elapsed time (s) was 59.096195936203
# Iteration 600 in epoch 16
# The averaged pixel error is (pixel in 256x256 image):  0.1410371780395508
# The averaged depth error is (mm):  0.17952289581298828
# The elapsed time (s) was 59.2968327999115
# Iteration 700 in epoch 16
# The averaged pixel error is (pixel in 256x256 image):  0.15876040140787762
# The averaged depth error is (mm):  0.18757734934488932
# The elapsed time (s) was 59.124587535858154
# Iteration 800 in epoch 16
# The averaged pixel error is (pixel in 256x256 image):  0.1432176717122396
# The averaged depth error is (mm):  0.21297873179117838
# The elapsed time (s) was 59.12401080131531
# Iteration 900 in epoch 16
# The averaged pixel error is (pixel in 256x256 image):  0.16914477030436198
# The averaged depth error is (mm):  0.31165682474772133
# The elapsed time (s) was 59.10766792297363
# Epoch 16
# The training averaged pixel error is (pixel in 256x256 image):  0.15162190500637582
# The training averaged depth error is (mm):  0.22985653371536352
# The elapsed time (s) was 554.3906922340393
# The learning rate is  0.0002
# Iteration 0 in epoch 17
# The averaged pixel error is (pixel in 256x256 image):  0.14562361399332682
# The averaged depth error is (mm):  0.1985617701212565
# The elapsed time (s) was 2.334455728530884
# Iteration 100 in epoch 17
# The averaged pixel error is (pixel in 256x256 image):  0.14071764628092448
# The averaged depth error is (mm):  0.16776846567789713
# The elapsed time (s) was 58.945335388183594
# Iteration 200 in epoch 17
# The averaged pixel error is (pixel in 256x256 image):  0.13659716288248697
# The averaged depth error is (mm):  0.21648961385091145
# The elapsed time (s) was 59.05703091621399
# Iteration 300 in epoch 17
# The averaged pixel error is (pixel in 256x256 image):  0.14740519205729166
# The averaged depth error is (mm):  0.224709955851237
# The elapsed time (s) was 59.086894273757935
# Iteration 400 in epoch 17
# The averaged pixel error is (pixel in 256x256 image):  0.1384852091471354
# The averaged depth error is (mm):  0.2407831319173177
# The elapsed time (s) was 59.02582669258118
# Iteration 500 in epoch 17
# The averaged pixel error is (pixel in 256x256 image):  0.15087313334147134
# The averaged depth error is (mm):  0.25469266255696615
# The elapsed time (s) was 59.06020379066467
# Iteration 600 in epoch 17
# The averaged pixel error is (pixel in 256x256 image):  0.13776077270507814
# The averaged depth error is (mm):  0.1922556686401367
# The elapsed time (s) was 59.060718059539795
# Iteration 700 in epoch 17
# The averaged pixel error is (pixel in 256x256 image):  0.13473388671875
# The averaged depth error is (mm):  0.3146369425455729
# The elapsed time (s) was 59.05964732170105
# Iteration 800 in epoch 17
# The averaged pixel error is (pixel in 256x256 image):  0.14201306660970053
# The averaged depth error is (mm):  0.21554768880208333
# The elapsed time (s) was 59.06266903877258
# Iteration 900 in epoch 17
# The averaged pixel error is (pixel in 256x256 image):  0.13731583913167317
# The averaged depth error is (mm):  0.17472398122151692
# The elapsed time (s) was 58.97009539604187
# Epoch 17
# The training averaged pixel error is (pixel in 256x256 image):  0.14715206666955608
# The training averaged depth error is (mm):  0.22410684790145818
# The elapsed time (s) was 553.4841165542603
# The learning rate is  0.0002
# Iteration 0 in epoch 18
# The averaged pixel error is (pixel in 256x256 image):  0.14808481852213543
# The averaged depth error is (mm):  0.18245377858479817
# The elapsed time (s) was 2.2162094116210938
# Iteration 100 in epoch 18
# The averaged pixel error is (pixel in 256x256 image):  0.14175787607828777
# The averaged depth error is (mm):  0.37783409118652345
# The elapsed time (s) was 58.99234986305237
# Iteration 200 in epoch 18
# The averaged pixel error is (pixel in 256x256 image):  0.1477957026163737
# The averaged depth error is (mm):  0.35787180582682293
# The elapsed time (s) was 58.998377084732056
# Iteration 300 in epoch 18
# The averaged pixel error is (pixel in 256x256 image):  0.15277264912923177
# The averaged depth error is (mm):  0.34153846740722654
# The elapsed time (s) was 59.015533447265625
# Iteration 400 in epoch 18
# The averaged pixel error is (pixel in 256x256 image):  0.139471804300944
# The averaged depth error is (mm):  0.2202630360921224
# The elapsed time (s) was 59.064244985580444
# Iteration 500 in epoch 18
# The averaged pixel error is (pixel in 256x256 image):  0.1385179901123047
# The averaged depth error is (mm):  0.2330102030436198
# The elapsed time (s) was 59.14385724067688
# Iteration 600 in epoch 18
# The averaged pixel error is (pixel in 256x256 image):  0.14080927530924478
# The averaged depth error is (mm):  0.1670077896118164
# The elapsed time (s) was 59.266191244125366
# Iteration 700 in epoch 18
# The averaged pixel error is (pixel in 256x256 image):  0.14030147552490235
# The averaged depth error is (mm):  0.1923904291788737
# The elapsed time (s) was 59.35462951660156
# Iteration 800 in epoch 18
# The averaged pixel error is (pixel in 256x256 image):  0.12481908162434896
# The averaged depth error is (mm):  0.1685723876953125
# The elapsed time (s) was 59.41552400588989
# Iteration 900 in epoch 18
# The averaged pixel error is (pixel in 256x256 image):  0.1388897705078125
# The averaged depth error is (mm):  0.24291297912597656
# The elapsed time (s) was 59.59670281410217
# Epoch 18
# The training averaged pixel error is (pixel in 256x256 image):  0.14370636432919928
# The training averaged depth error is (mm):  0.23537367120239333
# The elapsed time (s) was 555.0450205802917
# The learning rate is  0.0002
# Iteration 0 in epoch 19
# The averaged pixel error is (pixel in 256x256 image):  0.13184494018554688
# The averaged depth error is (mm):  0.14794387817382812
# The elapsed time (s) was 2.3262672424316406
# Iteration 100 in epoch 19
# The averaged pixel error is (pixel in 256x256 image):  0.13914347330729165
# The averaged depth error is (mm):  0.3565112050374349
# The elapsed time (s) was 59.43389391899109
# Iteration 200 in epoch 19
# The averaged pixel error is (pixel in 256x256 image):  0.1366478220621745
# The averaged depth error is (mm):  0.14302143096923828
# The elapsed time (s) was 59.47562599182129
# Iteration 300 in epoch 19
# The averaged pixel error is (pixel in 256x256 image):  0.15522417704264324
# The averaged depth error is (mm):  0.26496241251627606
# The elapsed time (s) was 59.52481412887573
# Iteration 400 in epoch 19
# The averaged pixel error is (pixel in 256x256 image):  0.1610528564453125
# The averaged depth error is (mm):  0.28399080912272134
# The elapsed time (s) was 59.390474796295166
# Iteration 500 in epoch 19
# The averaged pixel error is (pixel in 256x256 image):  0.1259954833984375
# The averaged depth error is (mm):  0.2762317657470703
# The elapsed time (s) was 59.347634077072144
# Iteration 600 in epoch 19
# The averaged pixel error is (pixel in 256x256 image):  0.13698331197102864
# The averaged depth error is (mm):  0.22328989664713542
# The elapsed time (s) was 59.40558886528015
# Iteration 700 in epoch 19
# The averaged pixel error is (pixel in 256x256 image):  0.14642932891845703
# The averaged depth error is (mm):  0.2158234405517578
# The elapsed time (s) was 59.41430854797363
# Iteration 800 in epoch 19
# The averaged pixel error is (pixel in 256x256 image):  0.14337389628092448
# The averaged depth error is (mm):  0.15352397918701172
# The elapsed time (s) was 59.38477969169617
# Iteration 900 in epoch 19
# The averaged pixel error is (pixel in 256x256 image):  0.11992279052734375
# The averaged depth error is (mm):  0.18570985158284506
# The elapsed time (s) was 59.23763608932495
# Epoch 19
# The training averaged pixel error is (pixel in 256x256 image):  0.13860298364306053
# The training averaged depth error is (mm):  0.20925877680468158
# The elapsed time (s) was 556.882631778717
# Save the network at /home/stanlew/src/kpam/mankey_recreate/training_checkpoints_all_data/checkpoint-20.pth
# The learning rate is  0.0002
# Iteration 0 in epoch 20
# The averaged pixel error is (pixel in 256x256 image):  0.14605882008870444
# The averaged depth error is (mm):  0.22498710632324218
# The elapsed time (s) was 2.1720657348632812
# Iteration 100 in epoch 20
# The averaged pixel error is (pixel in 256x256 image):  0.12290416717529297
# The averaged depth error is (mm):  0.1955469004313151
# The elapsed time (s) was 59.26429343223572
# Iteration 200 in epoch 20
# The averaged pixel error is (pixel in 256x256 image):  0.12967987060546876
# The averaged depth error is (mm):  0.1586219914754232
# The elapsed time (s) was 59.17425584793091
# Iteration 300 in epoch 20
# The averaged pixel error is (pixel in 256x256 image):  0.1285248565673828
# The averaged depth error is (mm):  0.21286524454752603
# The elapsed time (s) was 59.217278480529785
# Iteration 400 in epoch 20
# The averaged pixel error is (pixel in 256x256 image):  0.13986602783203125
# The averaged depth error is (mm):  0.16733545939127603
# The elapsed time (s) was 59.14362096786499
# Iteration 500 in epoch 20
# The averaged pixel error is (pixel in 256x256 image):  0.13719361623128254
# The averaged depth error is (mm):  0.21546234130859376
# The elapsed time (s) was 59.291502952575684
# Iteration 600 in epoch 20
# The averaged pixel error is (pixel in 256x256 image):  0.15707340240478515
# The averaged depth error is (mm):  0.2775657908121745
# The elapsed time (s) was 59.12720584869385
# Iteration 700 in epoch 20
# The averaged pixel error is (pixel in 256x256 image):  0.1442414093017578
# The averaged depth error is (mm):  0.17230228424072266
# The elapsed time (s) was 59.24321508407593
# Iteration 800 in epoch 20
# The averaged pixel error is (pixel in 256x256 image):  0.18453612009684245
# The averaged depth error is (mm):  0.19466259002685546
# The elapsed time (s) was 59.22045087814331
# Iteration 900 in epoch 20
# The averaged pixel error is (pixel in 256x256 image):  0.13676685333251953
# The averaged depth error is (mm):  0.17263120015462238
# The elapsed time (s) was 59.31114077568054
# Epoch 20
# The training averaged pixel error is (pixel in 256x256 image):  0.13754853982675344
# The training averaged depth error is (mm):  0.20643035716587635
# The elapsed time (s) was 555.0517239570618
# The learning rate is  0.0002
# Iteration 0 in epoch 21
# The averaged pixel error is (pixel in 256x256 image):  0.136969362894694
# The averaged depth error is (mm):  0.13862194061279298
# The elapsed time (s) was 2.2440807819366455
# Iteration 100 in epoch 21
# The averaged pixel error is (pixel in 256x256 image):  0.12893182118733723
# The averaged depth error is (mm):  0.17597078959147136
# The elapsed time (s) was 59.21288275718689
# Iteration 200 in epoch 21
# The averaged pixel error is (pixel in 256x256 image):  0.13928735097249348
# The averaged depth error is (mm):  0.21999471028645834
# The elapsed time (s) was 59.160529136657715
# Iteration 300 in epoch 21
# The averaged pixel error is (pixel in 256x256 image):  0.1271194839477539
# The averaged depth error is (mm):  0.1812698237101237
# The elapsed time (s) was 59.25832509994507
# Iteration 400 in epoch 21
# The averaged pixel error is (pixel in 256x256 image):  0.1234109369913737
# The averaged depth error is (mm):  0.22827184041341145
# The elapsed time (s) was 59.220507860183716
# Iteration 500 in epoch 21
# The averaged pixel error is (pixel in 256x256 image):  0.13503841400146485
# The averaged depth error is (mm):  0.19592882792154948
# The elapsed time (s) was 59.09122586250305
# Iteration 600 in epoch 21
# The averaged pixel error is (pixel in 256x256 image):  0.13271734873453775
# ...
# The training averaged depth error is (mm):  0.04608324285845656
# The elapsed time (s) was 556.0510580539703
# The learning rate is  2.0000000000000003e-06
# Iteration 0 in epoch 143
# The averaged pixel error is (pixel in 256x256 image):  0.05726620356241862
# The averaged depth error is (mm):  0.03934357643127442
# The elapsed time (s) was 2.4943692684173584
# Iteration 100 in epoch 143
# The averaged pixel error is (pixel in 256x256 image):  0.05557068506876628
# The averaged depth error is (mm):  0.04648907979329427
# The elapsed time (s) was 59.337624311447144
# Iteration 200 in epoch 143
# The averaged pixel error is (pixel in 256x256 image):  0.05667175928751628
# The averaged depth error is (mm):  0.06338692347208659
# The elapsed time (s) was 59.25787925720215
# Iteration 300 in epoch 143
# The averaged pixel error is (pixel in 256x256 image):  0.0545465087890625
# The averaged depth error is (mm):  0.04920747756958008
# The elapsed time (s) was 59.2896466255188
# Iteration 400 in epoch 143
# The averaged pixel error is (pixel in 256x256 image):  0.05227266311645508
# The averaged depth error is (mm):  0.038737433751424154
# The elapsed time (s) was 59.316346645355225
# Iteration 500 in epoch 143
# The averaged pixel error is (pixel in 256x256 image):  0.056299260457356774
# The averaged depth error is (mm):  0.04448941230773926
# The elapsed time (s) was 59.56400418281555
# Iteration 600 in epoch 143
# The averaged pixel error is (pixel in 256x256 image):  0.05141880671183268
# The averaged depth error is (mm):  0.0409683100382487
# The elapsed time (s) was 59.313315629959106
# Iteration 700 in epoch 143
# The averaged pixel error is (pixel in 256x256 image):  0.05948748270670573
# The averaged depth error is (mm):  0.043797057469685874
# The elapsed time (s) was 59.34051251411438
# Iteration 800 in epoch 143
# The averaged pixel error is (pixel in 256x256 image):  0.049227514266967774
# The averaged depth error is (mm):  0.03935828844706218
# The elapsed time (s) was 59.3456346988678
# Iteration 900 in epoch 143
# The averaged pixel error is (pixel in 256x256 image):  0.05744624455769857
# The averaged depth error is (mm):  0.05018162409464518
# The elapsed time (s) was 59.335036277770996
# Epoch 143
# The training averaged pixel error is (pixel in 256x256 image):  0.05681112527432318
# The training averaged depth error is (mm):  0.04680076563011703
# The elapsed time (s) was 556.5119135379791
# The learning rate is  2.0000000000000003e-06
# Iteration 0 in epoch 144
# The averaged pixel error is (pixel in 256x256 image):  0.05849530537923177
# The averaged depth error is (mm):  0.044387598037719724
# The elapsed time (s) was 2.350633382797241
# Iteration 100 in epoch 144
# The averaged pixel error is (pixel in 256x256 image):  0.059231478373209634
# The averaged depth error is (mm):  0.04508764902750651
# The elapsed time (s) was 59.356415033340454
# Iteration 200 in epoch 144
# The averaged pixel error is (pixel in 256x256 image):  0.05585428873697917
# The averaged depth error is (mm):  0.05205073992411296
# The elapsed time (s) was 59.34054732322693
# Iteration 300 in epoch 144
# The averaged pixel error is (pixel in 256x256 image):  0.055817794799804685
# The averaged depth error is (mm):  0.05123648643493652
# The elapsed time (s) was 59.46961545944214
# Iteration 400 in epoch 144
# The averaged pixel error is (pixel in 256x256 image):  0.046720209121704104
# The averaged depth error is (mm):  0.04885002136230469
# The elapsed time (s) was 59.44357991218567
# Iteration 500 in epoch 144
# The averaged pixel error is (pixel in 256x256 image):  0.05655466715494792
# The averaged depth error is (mm):  0.03898409843444824
# The elapsed time (s) was 59.35849857330322
# Iteration 600 in epoch 144
# The averaged pixel error is (pixel in 256x256 image):  0.0557843017578125
# The averaged depth error is (mm):  0.04104806900024414
# The elapsed time (s) was 59.272937059402466
# Iteration 700 in epoch 144
# The averaged pixel error is (pixel in 256x256 image):  0.06074767430623373
# The averaged depth error is (mm):  0.04287476221720377
# The elapsed time (s) was 59.317755460739136
# Iteration 800 in epoch 144
# The averaged pixel error is (pixel in 256x256 image):  0.05151905377705892
# The averaged depth error is (mm):  0.03941871960957845
# The elapsed time (s) was 59.36837339401245
# Iteration 900 in epoch 144
# The averaged pixel error is (pixel in 256x256 image):  0.05546606063842773
# The averaged depth error is (mm):  0.04190100351969401
# The elapsed time (s) was 59.396854639053345
# Epoch 144
# The training averaged pixel error is (pixel in 256x256 image):  0.056541272426333875
# The training averaged depth error is (mm):  0.0458502249904518
# The elapsed time (s) was 556.6413469314575
# Save the network at /home/stanlew/src/kpam/mankey_recreate/training_checkpoints_all_data/checkpoint-145.pth
# The learning rate is  2.0000000000000003e-06
# Iteration 0 in epoch 145
# The averaged pixel error is (pixel in 256x256 image):  0.0567434819539388
# The averaged depth error is (mm):  0.05130706469217936
# The elapsed time (s) was 2.6723203659057617
# Iteration 100 in epoch 145
# The averaged pixel error is (pixel in 256x256 image):  0.05508349736531575
# The averaged depth error is (mm):  0.056116161346435545
# The elapsed time (s) was 59.191590785980225
# Iteration 200 in epoch 145
# The averaged pixel error is (pixel in 256x256 image):  0.06408265431722006
# The averaged depth error is (mm):  0.03861098607381185
# The elapsed time (s) was 59.36326336860657
# Iteration 300 in epoch 145
# The averaged pixel error is (pixel in 256x256 image):  0.056358534495035806
# The averaged depth error is (mm):  0.049929513931274414
# The elapsed time (s) was 59.289693117141724
# Iteration 400 in epoch 145
# The averaged pixel error is (pixel in 256x256 image):  0.05029696782430013
# The averaged depth error is (mm):  0.04839858055114746
# The elapsed time (s) was 59.39868974685669
# Iteration 500 in epoch 145
# The averaged pixel error is (pixel in 256x256 image):  0.05625316619873047
# The averaged depth error is (mm):  0.05089815775553386
# The elapsed time (s) was 59.35809874534607
# Iteration 600 in epoch 145
# The averaged pixel error is (pixel in 256x256 image):  0.055767491658528644
# The averaged depth error is (mm):  0.048819055557250975
# The elapsed time (s) was 59.30709218978882
# Iteration 700 in epoch 145
# The averaged pixel error is (pixel in 256x256 image):  0.05207095781962077
# The averaged depth error is (mm):  0.04917709668477376
# The elapsed time (s) was 59.34361743927002
# Iteration 800 in epoch 145
# The averaged pixel error is (pixel in 256x256 image):  0.056051991780598956
# The averaged depth error is (mm):  0.07585482915242513
# The elapsed time (s) was 59.45021176338196
# Iteration 900 in epoch 145
# The averaged pixel error is (pixel in 256x256 image):  0.05723438262939453
# The averaged depth error is (mm):  0.043809369405110675
# The elapsed time (s) was 61.955909967422485
# Epoch 145
# The training averaged pixel error is (pixel in 256x256 image):  0.056601075012884486
# The training averaged depth error is (mm):  0.04656093698883035
# The elapsed time (s) was 559.6915893554688
# The learning rate is  2.0000000000000003e-06
# Iteration 0 in epoch 146
# The averaged pixel error is (pixel in 256x256 image):  0.054882259368896485
# The averaged depth error is (mm):  0.041641213099161786
# The elapsed time (s) was 2.4015042781829834
# Iteration 100 in epoch 146
# The averaged pixel error is (pixel in 256x256 image):  0.05117818514506022
# The averaged depth error is (mm):  0.03419403711954753
# The elapsed time (s) was 59.420796394348145
# Iteration 200 in epoch 146
# The averaged pixel error is (pixel in 256x256 image):  0.05877327601114909
# The averaged depth error is (mm):  0.05599263509114583
# The elapsed time (s) was 59.35406994819641
# Iteration 300 in epoch 146
# The averaged pixel error is (pixel in 256x256 image):  0.05475871404012044
# The averaged depth error is (mm):  0.03754388809204102
# The elapsed time (s) was 59.41516613960266
# Iteration 400 in epoch 146
# The averaged pixel error is (pixel in 256x256 image):  0.050627463658650715
# The averaged depth error is (mm):  0.040527512232462565
# The elapsed time (s) was 59.33033585548401
# Iteration 500 in epoch 146
# The averaged pixel error is (pixel in 256x256 image):  0.056010894775390625
# The averaged depth error is (mm):  0.07184720357259114
# The elapsed time (s) was 59.364986181259155
# Iteration 600 in epoch 146
# The averaged pixel error is (pixel in 256x256 image):  0.05555149714152018
# The averaged depth error is (mm):  0.04376885732014974
# The elapsed time (s) was 59.36762237548828
# Iteration 700 in epoch 146
# The averaged pixel error is (pixel in 256x256 image):  0.05812683741251628
# The averaged depth error is (mm):  0.050470136006673175
# The elapsed time (s) was 59.35890173912048
# Iteration 800 in epoch 146
# The averaged pixel error is (pixel in 256x256 image):  0.06172340393066406
# The averaged depth error is (mm):  0.044743035634358726
# The elapsed time (s) was 59.36358428001404
# Iteration 900 in epoch 146
# The averaged pixel error is (pixel in 256x256 image):  0.05863268534342448
# The averaged depth error is (mm):  0.04199829737345378
# The elapsed time (s) was 59.42891597747803
# Epoch 146
# The training averaged pixel error is (pixel in 256x256 image):  0.0565351127785657
# The training averaged depth error is (mm):  0.04630608540899414
# The elapsed time (s) was 556.7882053852081
# The learning rate is  2.0000000000000003e-06
# Iteration 0 in epoch 147
# The averaged pixel error is (pixel in 256x256 image):  0.054894962310791016
# The averaged depth error is (mm):  0.04358322461446126
# The elapsed time (s) was 2.6434967517852783
# Iteration 100 in epoch 147
# The averaged pixel error is (pixel in 256x256 image):  0.05360525131225586
# The averaged depth error is (mm):  0.04238745371500651
# The elapsed time (s) was 59.46183180809021
# Iteration 200 in epoch 147
# The averaged pixel error is (pixel in 256x256 image):  0.05736445109049479
# The averaged depth error is (mm):  0.03876963933308919
# The elapsed time (s) was 59.41841959953308
# Iteration 300 in epoch 147
# The averaged pixel error is (pixel in 256x256 image):  0.05406474431355794
# The averaged depth error is (mm):  0.04058604240417481
# The elapsed time (s) was 59.241021156311035
# Iteration 400 in epoch 147
# The averaged pixel error is (pixel in 256x256 image):  0.059632994333903
# The averaged depth error is (mm):  0.05239633878072103
# The elapsed time (s) was 59.41971182823181
# Iteration 500 in epoch 147
# The averaged pixel error is (pixel in 256x256 image):  0.05293731689453125
# The averaged depth error is (mm):  0.03717243512471517
# The elapsed time (s) was 59.27179670333862
# Iteration 600 in epoch 147
# The averaged pixel error is (pixel in 256x256 image):  0.053959986368815105
# The averaged depth error is (mm):  0.039027986526489256
# The elapsed time (s) was 59.41104483604431
# Iteration 700 in epoch 147
# The averaged pixel error is (pixel in 256x256 image):  0.05156896273295085
# The averaged depth error is (mm):  0.04593914349873861
# The elapsed time (s) was 59.32095718383789
# Iteration 800 in epoch 147
# The averaged pixel error is (pixel in 256x256 image):  0.0624339230855306
# The averaged depth error is (mm):  0.05554494857788086
# The elapsed time (s) was 59.37777543067932
# Iteration 900 in epoch 147
# The averaged pixel error is (pixel in 256x256 image):  0.05990029652913412
# The averaged depth error is (mm):  0.047582454681396484
# The elapsed time (s) was 59.27185916900635
# Epoch 147
# The training averaged pixel error is (pixel in 256x256 image):  0.05644789637861318
# The training averaged depth error is (mm):  0.04548230030589238
# The elapsed time (s) was 556.7960879802704
# The learning rate is  2.0000000000000003e-06
# Iteration 0 in epoch 148
# The averaged pixel error is (pixel in 256x256 image):  0.0553635025024414
# The averaged depth error is (mm):  0.039776299794514976
# The elapsed time (s) was 2.2352101802825928
# Iteration 100 in epoch 148
# The averaged pixel error is (pixel in 256x256 image):  0.05615914662679036
# The averaged depth error is (mm):  0.04589681625366211
# The elapsed time (s) was 59.38775944709778
# Iteration 200 in epoch 148
# The averaged pixel error is (pixel in 256x256 image):  0.05809466044108073
# The averaged depth error is (mm):  0.06215555826822917
# The elapsed time (s) was 59.237037897109985
# Iteration 300 in epoch 148
# The averaged pixel error is (pixel in 256x256 image):  0.059930248260498045
# The averaged depth error is (mm):  0.048781569798787436
# The elapsed time (s) was 59.29445695877075
# Iteration 400 in epoch 148
# The averaged pixel error is (pixel in 256x256 image):  0.05232645670572917
# The averaged depth error is (mm):  0.04720105489095052
# The elapsed time (s) was 59.3048574924469
# Iteration 500 in epoch 148
# The averaged pixel error is (pixel in 256x256 image):  0.06064147313435873
# The averaged depth error is (mm):  0.04057264010111491
# The elapsed time (s) was 59.29820251464844
# Iteration 600 in epoch 148
# The averaged pixel error is (pixel in 256x256 image):  0.05336345672607422
# The averaged depth error is (mm):  0.04708058993021647
# The elapsed time (s) was 59.28334975242615
# Iteration 700 in epoch 148
# The averaged pixel error is (pixel in 256x256 image):  0.058003997802734374
# The averaged depth error is (mm):  0.04566261609395345
# The elapsed time (s) was 59.32222628593445
# Iteration 800 in epoch 148
# The averaged pixel error is (pixel in 256x256 image):  0.05847885131835937
# The averaged depth error is (mm):  0.04555537223815918
# The elapsed time (s) was 59.398353099823
# Iteration 900 in epoch 148
# The averaged pixel error is (pixel in 256x256 image):  0.05883751551310221
# The averaged depth error is (mm):  0.04144499778747559
# The elapsed time (s) was 59.3778281211853
# Epoch 148
# The training averaged pixel error is (pixel in 256x256 image):  0.05654259737158283
# The training averaged depth error is (mm):  0.046251031142701286
# The elapsed time (s) was 556.0740427970886
# The learning rate is  2.0000000000000003e-06
# Iteration 0 in epoch 149
# The averaged pixel error is (pixel in 256x256 image):  0.06384761174519857
# The averaged depth error is (mm):  0.05102802912394206
# The elapsed time (s) was 2.1805741786956787
# Iteration 100 in epoch 149
# The averaged pixel error is (pixel in 256x256 image):  0.05776871999104818
# The averaged depth error is (mm):  0.06725561777750651
# The elapsed time (s) was 59.314645528793335
# Iteration 200 in epoch 149
# The averaged pixel error is (pixel in 256x256 image):  0.05956536610921224
# The averaged depth error is (mm):  0.04274719556172689
# The elapsed time (s) was 59.32767915725708
# Iteration 300 in epoch 149
# The averaged pixel error is (pixel in 256x256 image):  0.057693710327148436
# The averaged depth error is (mm):  0.05151075998942057
# The elapsed time (s) was 59.35866570472717
# Iteration 400 in epoch 149
# The averaged pixel error is (pixel in 256x256 image):  0.0535008430480957
# The averaged depth error is (mm):  0.04798988978068034
# The elapsed time (s) was 59.34809947013855
# Iteration 500 in epoch 149
# The averaged pixel error is (pixel in 256x256 image):  0.05634559631347656
# The averaged depth error is (mm):  0.039038991928100585
# The elapsed time (s) was 59.31915640830994
# Iteration 600 in epoch 149
# The averaged pixel error is (pixel in 256x256 image):  0.059151954650878906
# The averaged depth error is (mm):  0.05238900820414225
# The elapsed time (s) was 59.22901368141174
# Iteration 700 in epoch 149
# The averaged pixel error is (pixel in 256x256 image):  0.06108482360839844
# The averaged depth error is (mm):  0.04732715924580892
# The elapsed time (s) was 59.27918195724487
# Iteration 800 in epoch 149
# The averaged pixel error is (pixel in 256x256 image):  0.05282553990681966
# The averaged depth error is (mm):  0.041535800298055016
# The elapsed time (s) was 59.280921936035156
# Iteration 900 in epoch 149
# The averaged pixel error is (pixel in 256x256 image):  0.05683764139811198
# The averaged depth error is (mm):  0.0367617670694987
# The elapsed time (s) was 59.36667990684509
# Epoch 149
# The training averaged pixel error is (pixel in 256x256 image):  0.056491026253313446
# The training averaged depth error is (mm):  0.046398083071880515
# The elapsed time (s) was 555.9422972202301

# %%
file_name = 'checkpoint-%d.pth' % (n_epoch + save_epoch_offset)
checkpoint_path = os.path.join(checkpoint_dir, file_name)
print('Save the network at %s' % checkpoint_path)
torch.save(network.state_dict(), checkpoint_path)
# Out:
# Save the network at /home/stanlew/src/kpam/mankey_recreate/training_checkpoints_all_data/checkpoint-150.pth

# %%
kpDbConfig = KeypointDBConfig()
kpDbConfig.pdc_data_root = "/home/stanlew/src/kpam/data/"
#kpDbConfig.config_file_path = "/home/stanlew/src/kpam/mankey_recreate/kpnet/config/mugs_test_single.txt"
kpDbConfig.config_file_path = "/home/stanlew/src/kpam/mankey_recreate/kpnet/config/mugs_20190221.txt"
#kpDbConfig.config_file_path = "/home/stanlew/src/kpam/mankey_recreate/kpnet/config/mugs_alldata.txt"
kpDbConfig.keypoint_yaml_name = "mug_3_keypoint_image.yaml"
